# %%
#import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data=pd.read_excel(r'C:\Users\Admin\Documents\Data_Science_Projects\Stock_Price_Analysis\Stock_Price_data_set.xlsx')

# %%
data
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1    2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2    2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3    2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4    2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...         ...         ...         ...         ...         ...         ...
# 1004 2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005 2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006 2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007 2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008 2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#         Volume
# 0     11896100
# 1     12595800
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1009 non-null   datetime64[ns]
#  1   Open       1009 non-null   float64
#  2   High       1009 non-null   float64
#  3   Low        1009 non-null   float64
#  4   Close      1009 non-null   float64
#  5   Adj Close  1009 non-null   float64
#  6   Volume     1009 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 55.3 KB

# %%
data.shape
# Out:
# (1009, 7)

# %%
#Check whether there is a data missing in any column.
#If the count is less than 1009 then , there should be missing data in that particular column.
data.count()
# Out:
# Date         1009
# Open         1009
# High         1009
# Low          1009
# Close        1009
# Adj Close    1009
# Volume       1009
# dtype: int64

# %%
# As per the result there is no missing data.
# Let's check data types of the columns.
data.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
# get the mean, standerd deviation etc. of the given data.
data.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           1009  1009.000000  1009.000000  1009.000000
# mean   2020-02-05 07:30:58.870168320   419.059673   425.320703   412.374044
# min              2018-02-05 00:00:00   233.919998   250.649994   231.229996
# 25%              2019-02-06 00:00:00   331.489990   336.299988   326.000000
# 50%              2020-02-06 00:00:00   377.769989   383.010010   370.880005
# 75%              2021-02-05 00:00:00   509.130005   515.630005   502.529999
# max              2022-02-04 00:00:00   692.349976   700.989990   686.090027
# std                              NaN   108.537532   109.262960   107.555867
#
#              Close    Adj Close        Volume
# count  1009.000000  1009.000000  1.009000e+03
# mean    419.000733   419.000733  7.570685e+06
# min     233.880005   233.880005  1.144000e+06
# 25%     331.619995   331.619995  4.091900e+06
# 50%     378.670013   378.670013  5.934500e+06
# ...

# %%
x_axis=data['Date']
y_axis=data['Close']
plt.bar(x_axis,y_axis,width=5)
plt.xlabel("Date")
plt.ylabel("Clossing Value")
plt.show()

# sb.set(style='whitegrid')
# data1=data.head()
# final_data=sb.get_dataset_names("data1")
# sb.boxplot(x='Date',y='Close',data='final_data')

# %%
from matplotlib import rcParams
rcParams['figure.figsize']=15,6
plt.plot(data.Date,data.Close);  # take the value of column Date and 'Close'; Syntax matplotlib.plot(x,y) 
plt.plot(data.Date,data.Open);
plt.title("Share Price variation with respect to time")
plt.xlabel("Date")
plt.ylabel("Price")
plt.ylim(100,1400)
plt.grid(True,color='k',linestyle=':')
plt.legend(["Close","Open"],fontsize="x-large",loc=1);

# %%
data["Tomorrow"]=data["Close"].shift(-1)
# Add one column to the dataframe, column name=Tomorrow; value =Close price of next days.

# %%
data
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1    2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2    2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3    2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4    2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...         ...         ...         ...         ...         ...         ...
# 1004 2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005 2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006 2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007 2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008 2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#         Volume    Tomorrow
# 0     11896100  265.720001
# ...

# %%
data.plot.line(x="Date",y="Tomorrow",use_index=True)
# Plot Tomorrow's price w.r.t Date, using line index.
# Out:
# <Axes: xlabel='Date'>
